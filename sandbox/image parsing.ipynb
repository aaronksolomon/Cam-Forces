# %%
import base64

# Path to your image
image_path = "/Users/phapman/Desktop/Cam-Forces/cam_force_diagram.png"

# Read the image file in binary mode
with open(image_path, "rb") as image_file:
    base64_string = base64.b64encode(image_file.read()).decode("utf-8")

# Print the base64 string (or save it to a file)
print(base64_string)
# Out:
# ...

# %%
<img src="......" alt="Cam Forces Diagram" style="width:600px;"/>
